# %%
from astropy.io import fits

# open fits file as fits_file
fits_file = fits.open('ngc1261.fits')
print(fits_file)
# Out:
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x000001F861780E10>]

# %%
# discect fits file information and data
fits_file.info()
image_data = fits_file[0].data
print(image_data)
# Out:
# Filename: ngc1261.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      37   (10000, 10000)   float32
# [[-25. -25. -25. ... -25. -25. -25.]
#  [-25. -25. -25. ... -25. -25. -25.]
#  [-25. -25. -25. ... -25. -25. -25.]
#  ...
#  [-25. -25. -25. ... -25. -25. -25.]
#  [-25. -25. -25. ... -25. -25. -25.]
#  [-25. -25. -25. ... -25. -25. -25.]]

# %%
# dispay image with matplotlib
import matplotlib.pyplot as plt

plt.figure()
plt.imshow(image_data, origin = 'lower')
plt.colorbar()
plt.show()

# %%
# add LogNorm and change cmap to 'Greys'
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

plt.figure()
plt.imshow(image_data, origin = 'lower', cmap='Greys', norm=LogNorm())
plt.colorbar()
plt.show()

# %%
# only display a portion of the data
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# change working data to "image_data[y:y, x:x]"
section1 = image_data[2250:2650, 5350:5950]

# plt.imshow "image_data_1" instead of "image_data"
plt.figure()
plt.imshow(section1, origin = 'lower', cmap='Greys', norm=LogNorm())
plt.colorbar()
plt.show()
